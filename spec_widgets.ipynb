# %%
# %matplotlib notebook
import spec_nbwidgets
reload(spec_nbwidgets)
sw=spec_nbwidgets.SpectralAnalysis()
sw.make_widgets()
# Out:
# A Jupyter Widget
# <img src="data:image/png;base64,..." width="640">
